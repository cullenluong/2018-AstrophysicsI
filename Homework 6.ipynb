# %% [markdown]
# # Cullen Luong
# # Astrophysics 713
# # Homework 6

# %% [markdown]
# # 4a.)
#
# Joint electrostaitc potential equals kinetic.
#
# $\sigma = \pi r^2 $
#
# $\frac{e^2}{r} = k T $
#
# $r = \frac{e^2}{k T} $
#
# Combined above to solve for cross section
# $\sigma = \frac{\pi e^4}{k^2 T^2} $

# %% [markdown]
# # 5.)
#
# a.)
#
# $\epsilon_1 = \frac { 1 } { \gamma - 1 } \frac { k T_1 } { \overline { m } } $
#
# $E _ { k , 0 } = \frac{1}{2}v_0^2 $
#
#
#
# Eq 5.62
#
# $ T_1= \frac { 2 ( \gamma - 1 ) } { ( \gamma + 1 ) ^ { 2 } } \frac { \overline { m } } { k } v _ { 0 } ^ { 2 }
# =  \frac { 4 ( \gamma - 1 ) } { ( \gamma + 1 ) ^ { 2 } } \frac { \overline { m } } { k } KE
# $
#
# Combined First two equations with 5.62 to get
#
# $\frac{\epsilon}{E _ { k , 0 }} = \frac{4 }{(\gamma +1)^2} = \frac{4}{(8/3)^2} = \frac{9}{16}$
#
#
# b.)
#
# $\frac { \rho _ { 1 } } { \rho _ { 0 } } = \frac { \mathrm { v } _ { 0 } } { \mathrm { v } _ { 1 } }= \frac { \gamma + 1 } { \gamma - 1 }$
#
# $\frac{E _ { k ,S, 1 }}{E _ { k , 0 }} = \frac{v_1^2}{v_0^2} = \frac{(\gamma - 1 )^2}{(\gamma + 1 )^2}$
# $\frac{E _ { k ,S, 1 }}{E _ { k , 0 }} = \frac{(2/3)^2}{(8/3)^2} = \frac{1}{16} $
#
# c.)
#
# $ v = v_0 - v_1$
#
# $\frac{v^2}{v_0^2} = (1 -\frac{v_1}{v_0})^2 = (1-\frac{\gamma-1}{\gamma+1})^2  = (\frac{2}{\gamma+1})^2 $
#
# $\frac{v^2}{v_0^2} =  \frac{4 }{(\gamma +1)^2} = \frac{4}{(8/3)^2} = \frac{9}{16}$

# %% [markdown]
# # 6. v = 6000 km s, h vsync = 4 keV d = 0.1 pc
#
# a.)
# $v_1 = v_0/4 $
#
# $t_{ \mathrm {cool}} = 10 \mathrm { yr } \frac { 1 } { \gamma B ^ { 2 } }$
#
#
# $t_{ \mathrm {cool}} = \frac{d}{v_1} = \frac{4\times 0.1 \times 3\times 10^{16} m }{6\times 10^{6}m \cdot s^{-1}}    $
#
#
# $t_{ \mathrm {cool}}  = 2 \times 10^{9} s = 70 \mathrm{yrs}  $
#
# $\nu_{\mathrm{sync}} = 4.2$ MHz $\gamma ^ { 2 } B $
#
#
# $h \nu_{\mathrm{peak}} = 4 keV  $
#
# $\nu_{\mathrm{sync}}  = \frac{4 \times 10^3 \mathrm{eV} }{0.29 \times 4.135 \times 10^{-15} eV \cdot s } = 3 \times 10^{12}\mathrm{MHz}$
#
# Combining above and solving for B we get
#
# $B = ( \frac{4.2 \mathrm{MHz}}{\nu_{\mathrm{sync}}   }  (\frac{10 \mathrm{yrs}}{ t_{\mathrm{cool}}})^2)^{1/3} $
#
#
# $B =  ( \frac{4.2 \mathrm{MHz}}{3 \times 10^{12}\mathrm{MHz}  }  (\frac{10 \mathrm{yrs}}{ 70})^2)^{1/3}   $
#
#
# $B = 3 \times 10^{-5} G = 30 \mathrm{\mu G} $
#
# $\gamma =  t_{ \mathrm {cool}}/10\mathrm{yrs}/B^2 = 7/(3\times 10^{-5})^2 = 1.8 \times 10^8$
#
#
# Range of energies for electron is
#
# $E = \gamma mc^2 = 1.8 \times 10^8 \times  \mathrm{0.511 meV}$
#
# $E = 10^8 \mathrm{meV} = 10^{14} \mathrm{eV}  $
#
# b.)
#
# $d \propto t $
#
# $t \propto 1/\gamma $
#
# $\nu \propto E_{photon} $
#
# $\nu \propto \gamma^2 B $
#
# $\gamma \propto \sqrt{\nu} $
#
# Since energy is 1/4 of above, $\nu$ is 1/4, gamma is 1/2, and t and d is doubled.
# Therefore d = 0.2 pc
#
# If rim width was found to be indepedent of energy, then we must assume that B is not constant. This is because gamma must change since energy changed, and for d to not change B must vary in some way.
